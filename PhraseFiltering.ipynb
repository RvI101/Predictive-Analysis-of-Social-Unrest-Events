# %%
# Performs the token-base rule matching using spaCy on all news article bodies in the dataset.

# %%
import pandas as pd
import json
import mlconjug
import spacy
import en_core_web_sm
from spacy.matcher import Matcher
nlp = en_core_web_sm.load()

# %%
def findFirstDate(doc, start, end):
    date = ""
    for i in range(start,end):
        if doc[i].ent_type_ == 'DATE':
            if doc[i].ent_iob_ == 'B' and doc[i+1].ent_type_ == 'DATE':
                date += doc[i].text +" "+ doc[i+1].text
            else:
                date = doc[i].text
            return date

# %%
newsdata = pd.read_csv('Hindu-Scraper/output.csv', error_bad_lines=False, warn_bad_lines=False)
newsdata['is_event'] = 0
newsdata
# Out:
#                                                    title        location  \
# 0      SC suspends eco clearance for international ai...       NEW DELHI
# 1       ‘Bid to dislodge AIADMK from T.N. won’t succeed’         Vellore
# 2      Centre turns down Bengal’s request for paramil...         Kolkata
# 3                                   Prayers before polls     Tirunelveli
# 4      ‘Christian missionaries’ contribution to Tamil...         MADURAI
# 5                     Cases booked for violation of code       THANJAVUR
# 6                  Tipparaju Hawaldar’s supporters angry         RAICHUR
# 7                            BJP, a betrayer: Mutharasan       THANJAVUR
# 8                                               31brief2      Vijayawada
# 9                                            Water level     Tirunelveli
# 10                                  Prayers before polls     Tirunelveli
# 11                 Stalin says DMK secured Cauvery water         VELLORE
# 12     ‘Vasanthakumar trying to block development pro...       Nagercoil
# 13     Youth collective goes on campaign trail in sup...         CHENNAI
# 14     ‘Mettur Dam surplus water scheme will be imple...           Salem
# 15           Four held for possession of country pistols         TIRUCHI
# 16                        10-year-old boy drowns in lake           HOSUR
# 17     ‘Stalin cannot find fault with AIADMK government’       THANJAVUR
# 18     ‘Blue Mountains’ beset by land issues, jobs an...  UDHAGAMANDALAM
# 19                   26 injured as bus falls off flyover      Coimbatore
# 20       Residents’ association installs 16 CCTV cameras  UDHAGAMANDALAM
# 21                   26 injured as bus falls off flyover      Coimbatore
# 22     Lok Sabha polls will decide destiny of the nat...      PUDUCHERRY
# 23                                           Water level         Madurai
# 24                                           Liquor woes       Thanjavur
# 25     At city bus stands, women face more verbal har...         MADURAI
# 26            Symbols allotted to independent candidates           ERODE
# 27                        PG medical, dental counselling         CHENNAI
# 28     Bid to dislodge AIADMK will not succeed: Panne...         VELLORE
# 29      VCK president moves HC seeking police protection         Chennai
# ...                                                  ...             ...
# 13495  Beluga whale with Russian harness raises alarm...      COPENHAGEN
# 13496                                Causing destruction           Paris
# 13497               Hales out of England World Cup squad          LONDON
# 13498            Man trapped in hole he dug to spy on ex     Mexico City
# 13499                       Made in Moscow for the world          Moscow
# 13500  3,000-kg garbage collected from Mt Everest, as...       Kathmandu
# 13501  Lawyer fighting palm oil industry wins ecology...          Boston
# 13502                          What’s in your sunscreen?     KAILUA-KONA
# 13503        Madrid misery continues with defeat at Rayo          Madrid
# 13504        Warriors edge Rockets, Celtics baffle Bucks      Washington
# 13505             Lille close on Champions League return           Paris
# 13506                            Crawling to extinction?       SINGAPORE
# 13507  Opening or floating, talented Gill ‘happy’ to ...        Kolkata:
# 13508         Indonesia floods, landslides: toll goes up         Jakarta
# 13509  This popular food preservative may up obesity ...          Boston
# 13510  Bayern survive penalty drama as Nuremberg keep...          Berlin
# 13521  mumbai indians skipper rohit sharma indian pre...       0          NaN
# 13522  playing black widow aka natalia romanova since...       0          NaN
# 13523  dash rajasthan royals ’ faint play captaincy –...       0          NaN
# 13524  mumbai indians ’ quinton de kock two shots any...       0          NaN
#
#        actors  is_event
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0
# 5         NaN         0
# 6         NaN         0
# 7         NaN         0
# 8         NaN         0
# 9         NaN         0
# 10        NaN         0
# 11        NaN         0
# 12        NaN         0
# 13        NaN         0
# 14        NaN         0
# 15        NaN         0
# 16        NaN         0
# 17        NaN         0
# 18        NaN         0
# 19        NaN         0
# 20        NaN         0
# 21        NaN         0
# 22        NaN         0
# 23        NaN         0
# 24        NaN         0
# 25        NaN         0
# 26        NaN         0
# 27        NaN         0
# 28        NaN         0
# 29        NaN         0
# ...       ...       ...
# 13495     NaN         0
# 13496     NaN         0
# 13497     NaN         0
# 13498     NaN         0
# 13499     NaN         0
# 13500     NaN         0
# 13501     NaN         0
# 13502     NaN         0
# 13503     NaN         0
# 13504     NaN         0
# 13505     NaN         0
# 13506     NaN         0
# 13507     NaN         0
# 13508     NaN         0
# 13509     NaN         0
# 13510     NaN         0
# 13511     NaN         0
# 13512     NaN         0
# 13513     NaN         0
# 13514     NaN         0
# 13515     NaN         0
# 13516     NaN         0
# 13517     NaN         0
# 13518     NaN         0
# 13519     NaN         0
# 13520     NaN         0
# 13521     NaN         0
# 13522     NaN         0
# 13523     NaN         0
# 13524     NaN         0
#
# [13525 rows x 9 columns]

# %%
verb_list = ['organize', 'plan', 'announce', 'prepare', 'demand', 'stage', 'call', 'hold']
noun_list = ['demonstration', 'march', 'protest', 'strike', 'bandh', 'dharna', 'union', 'riot', 'march', 'gathering', 'attack']

# %%
phrase_list = []
for v in verb_list:
    for n in noun_list:
        phrase_list.append((v, n))
phrase_list
# Out:
# [('organize', 'demonstration'),
#  ('organize', 'march'),
#  ('organize', 'protest'),
#  ('organize', 'strike'),
#  ('organize', 'bandh'),
#  ('organize', 'dharna'),
#  ('organize', 'union'),
#  ('organize', 'riot'),
#  ('organize', 'march'),
#  ('organize', 'gathering'),
#  ('organize', 'attack'),
#  ('plan', 'demonstration'),
#  ('plan', 'march'),
#  ('plan', 'protest'),
#  ('plan', 'strike'),
#  ('plan', 'bandh'),
#  ('plan', 'dharna'),
#  ('plan', 'union'),
#  ('plan', 'riot'),
#  ('plan', 'march'),
#  ('plan', 'gathering'),
#  ('plan', 'attack'),
#  ('announce', 'demonstration'),
#  ('announce', 'march'),
#  ('announce', 'protest'),
#  ('announce', 'strike'),
#  ('announce', 'bandh'),
#  ('announce', 'dharna'),
#  ('announce', 'union'),
#  ('announce', 'riot'),
#  ('announce', 'march'),
#  ('announce', 'gathering'),
#  ('announce', 'attack'),
#  ('prepare', 'demonstration'),
#  ('prepare', 'march'),
#  ('prepare', 'protest'),
#  ('prepare', 'strike'),
#  ('prepare', 'bandh'),
#  ('prepare', 'dharna'),
#  ('prepare', 'union'),
#  ('prepare', 'riot'),
#  ('prepare', 'march'),
#  ('prepare', 'gathering'),
#  ('prepare', 'attack'),
#  ('demand', 'demonstration'),
#  ('demand', 'march'),
#  ('demand', 'protest'),
#  ('demand', 'strike'),
#  ('demand', 'bandh'),
#  ('demand', 'dharna'),
#  ('demand', 'union'),
#  ('demand', 'riot'),
#  ('demand', 'march'),
#  ('demand', 'gathering'),
#  ('demand', 'attack'),
#  ('stage', 'demonstration'),
#  ('stage', 'march'),
#  ('stage', 'protest'),
#  ('stage', 'strike'),
#  ('stage', 'bandh'),
#  ('stage', 'dharna'),
#  ('stage', 'union'),
#  ('stage', 'riot'),
#  ('stage', 'march'),
#  ('stage', 'gathering'),
#  ('stage', 'attack'),
#  ('call', 'demonstration'),
#  ('call', 'march'),
#  ('call', 'protest'),
#  ('call', 'strike'),
#  ('call', 'bandh'),
#  ('call', 'dharna'),
#  ('call', 'union'),
#  ('call', 'riot'),
#  ('call', 'march'),
#  ('call', 'gathering'),
#  ('call', 'attack'),
#  ('hold', 'demonstration'),
#  ('hold', 'march'),
#  ('hold', 'protest'),
#  ('hold', 'strike'),
#  ('hold', 'bandh'),
#  ('hold', 'dharna'),
#  ('hold', 'union'),
#  ('hold', 'riot'),
#  ('hold', 'march'),
#  ('hold', 'gathering'),
#  ('hold', 'attack')]

# %%
# Generate rules for matching
# VP TOKEN* NP
# NP TOKEN* VP
def generate_patterns(phrase_list):
    patterns = []
    for phrase in phrase_list:
        patterns.append([{'LEMMA': phrase[0], 'POS': 'VERB'},
                   {'IS_ALPHA': True, 'OP': '*'},
                   {'POS': 'NOUN', 'LEMMA': phrase[1]}])
        
        patterns.append([{'LEMMA': phrase[1], 'POS': 'NOUN'},
               {'IS_ALPHA': True, 'OP': '*'},
               {'POS': 'VERB', 'LEMMA': phrase[0]}])          
    return patterns

def generate_date_patterns(phrase_list):
    patterns = []
    for phrase in phrase_list:
        patterns.append([{'LEMMA': phrase[0], 'POS': 'VERB'},
                   {'IS_ALPHA': True, 'OP': '*'},
                   {'POS': 'NOUN', 'LEMMA': phrase[1]}, 
                {'IS_ALPHA': True, 'OP': '*'},
               {'ENT_TYPE': 'DATE'}])
        
        patterns.append([{'LEMMA': phrase[1], 'POS': 'NOUN'},
               {'IS_ALPHA': True, 'OP': '*'},
               {'POS': 'VERB', 'LEMMA': phrase[0]},
                {'IS_ALPHA': True, 'OP': '*'},
           {'ENT_TYPE': 'DATE'}])              
    return patterns
patterns = generate_patterns(phrase_list)
date_patterns = generate_date_patterns(phrase_list)

# %%
# Token-based rule matching is performed. Takes a while.
matcher = Matcher(nlp.vocab)
matcher.add("RiotPlanning", None, *patterns)
newsdata['raw_target_date'] = ''
newsdata['actors'] = ''
newsdata['actors'] = newsdata.astype(object)
for row, article in newsdata.iterrows():
    doc = nlp(article.get('body'))
    matches = matcher(doc)
    if matches:
        newsdata.at[row, 'is_event'] = 1
        newsdata.at[row, 'actors'] = [e.text for e in doc.ents if e[0].ent_type_ in ['ORG', 'GPE', 'PERSON']]
        for match_id, start, end in matches:
            date = findFirstDate(doc, start, len(doc))
            newsdata.at[row,'raw_target_date'] = date
            break
print('Done')
# Out:
# Done

# %%
newsdata.at[423, 'body']
# newsdata.to_csv('Hindu-Scraper/newsJ2MLabelledAll.csv', sep='|', index=False)
